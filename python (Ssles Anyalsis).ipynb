# %%
import pandas as pd

# %%
import pandas as pd
 # step 1 = data collect in dataset . and put the dataset in kaggle
a = pd.read_csv(
    '/kaggle/input/datasets/sumitpathak52/project-dataset/Sample - Superstore.csv',
    encoding='latin1' # kis Pandas ko batana ki CSV file ke text ko kis encoding ke according read karna hai.
    # yeh baata hain ki pura csv file ko read karna or 
)

a # yeh file print kara rhi hain
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
# sirf puri row dekhne ke liye 
#a = pd.set_option('display.max_rows', None)
#a

# %%
#a = pd.set_option('display.max_columns', None) # isme sare columns ko seen kr skate hai 
#a

# %%
#Step = 2 data import karna .
a.head() # default me 5 value show karta hain
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
a.shape # row and # columns baata hain
# Out:
# (9994, 21)

# %%
a.info # missing value or data type ka identify kiya hain 
# hamere isme 5 cartiera hain like = 1. order details , 2.coustomer details, 3.country details , 4.product id ,name ,type details  , 5. sales,quantity,profit,discount like this
# Out:
# <bound method DataFrame.info of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
a.head() # or yeh top ki 5 row leta hain
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
a.tail() # bottom ki row ko leta hain
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
a.sample()  # or yeh koi rnadom row leta hain
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2836    2837  CA-2017-110842  11/11/2017  11/16/2017  Standard Class
#
#      Customer ID  Customer Name   Segment        Country         City  ...  \
# 2836    GA-14725  Guy Armstrong  Consumer  United States  Los Angeles  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 2836       90036    West  OFF-PA-10000520  Office Supplies        Paper
#
#      Product Name  Sales  Quantity  Discount  Profit
# 2836    Xerox 201  19.44         3       0.0  9.3312
#
# [1 rows x 21 columns]

# %%
#step = 3 data cleaning 
a.isnull().sum() # isse hame apne data me se null ko dekha
# df = df.dropna() # missing value ko handle karne ke liye
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
a.duplicated().sum() # duplicated ka mtlb hain ki value ko check karna ki duplicate value to nhi h 
# duplicate value ko remove karne ke liye use karo ( df = df.drop_duplicates() ).
# Out:
# np.int64(0)

# %%
a['Order Date'] = pd.to_datetime(a['Order Date']) # mtlb date ko order me karna ( year/month/date )
a
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 1          2  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 2          3  CA-2016-138688 2016-06-12   6/16/2016    Second Class
# 3          4  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# 4          5  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# ...      ...             ...        ...         ...             ...
# 9989    9990  CA-2014-110422 2014-01-21   1/23/2014    Second Class
# 9990    9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
a['Order Date'].dtype # yeh datatype baata hain
# Out:
# dtype('<M8[ns]')

# %%
# Step 4: Exploratory Data Analysis (EDA)
import numpy as np
a
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 1          2  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 2          3  CA-2016-138688 2016-06-12   6/16/2016    Second Class
# 3          4  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# 4          5  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# ...      ...             ...        ...         ...             ...
# 9989    9990  CA-2014-110422 2014-01-21   1/23/2014    Second Class
# 9990    9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
a['Sales'].sum() # yeh sales ka total kr rha hain itni sales hoi hain .
# Out:
# np.float64(2297200.8603000003)

# %%
a['Profit'].sum() #total profit
# Out:
# np.float64(286397.0217)

# %%
a['Quantity'].sum() # total quantity
# Out:
# np.int64(37873)

# %%
a.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
a.groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
a.groupby('City')['Sales'].sum()
# Out:
# City
# Aberdeen         25.500
# Abilene           1.392
# Akron          2729.986
# Albuquerque    2220.160
# Alexandria     5519.570
#                  ...
# Woonsocket      195.550
# Yonkers        7657.666
# York            817.978
# Yucaipa          50.800
# Yuma            840.865
# Name: Sales, Length: 531, dtype: float64

# %%
a.groupby('City')['Profit'].sum()
# Out:
# City
# Aberdeen          6.6300
# Abilene          -3.7584
# Akron          -186.6356
# Albuquerque     634.0881
# Alexandria      318.6183
#                  ...
# Woonsocket       78.6791
# Yonkers        2767.7557
# York           -102.1692
# Yucaipa          13.2080
# Yuma           -465.9909
# Name: Profit, Length: 531, dtype: float64

# %%
a
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 1          2  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 2          3  CA-2016-138688 2016-06-12   6/16/2016    Second Class
# 3          4  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# 4          5  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# ...      ...             ...        ...         ...             ...
# 9989    9990  CA-2014-110422 2014-01-21   1/23/2014    Second Class
# 9990    9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
a.groupby('Order Date')['Sales'].sum()
# Out:
# Order Date
# 2014-01-03      16.4480
# 2014-01-04     288.0600
# 2014-01-05      19.5360
# 2014-01-06    4407.1000
# 2014-01-07      87.1580
#                 ...
# 2017-12-26     814.5940
# 2017-12-27     177.6360
# 2017-12-28    1657.3508
# 2017-12-29    2915.5340
# 2017-12-30     713.7900
# Name: Sales, Length: 1237, dtype: float64

# %%
a.groupby('Order Date')['Profit'].sum()
# Out:
# Order Date
# 2014-01-03       5.5512
# 2014-01-04     -65.9901
# 2014-01-05       4.8840
# 2014-01-06    1358.0524
# 2014-01-07     -71.9621
#                 ...
# 2017-12-26      61.1202
# 2017-12-27     -31.9742
# 2017-12-28     253.1188
# 2017-12-29     644.4338
# 2017-12-30     101.5365
# Name: Profit, Length: 1237, dtype: float64

# %%
a['Profit'].mean()
# Out:
# np.float64(28.65689630778467)
